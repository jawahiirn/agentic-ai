# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')
gemini_api_key = os.getenv('GEMINI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Gemini API Key exists and begins AQ.Ab8RN

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Fun fact: Octopuses have three hearts—two pump blood to the gills, and one pumps it to the rest of the body. Also, their blood is blue!

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A researcher has 12 seemingly identical balls. One of them is either heavier or lighter than the others, but you do not know which. Using a balance scale exactly three times, how can you determine which ball is different and whether it is heavier or lighter?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# 1. Ask the LLM to pick a business area worth exploring for Agentic AI

messages = [{"role": "user", "content": "Suggest a business area worth exploring for an Agentic AI opportunity. Respond with just the name."}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
business_area = response.choices[0].message.content
print(f"Business area: {business_area}")

# 2. Ask the LLM to present a pain-point in that industry

messages = [{"role": "user", "content": f"In the {business_area} industry, what is a challenging pain-point that might be ripe for an Agentic AI solution? Respond with just the pain-point."}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
pain_point = response.choices[0].message.content
print(f"Pain-point: {pain_point}")

# 3. Have the third LLM call propose the Agentic AI solution

messages = [{"role": "user", "content": f"In the {business_area} industry, the pain-point is: {pain_point}. Propose an Agentic AI solution to address this."}]
response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
solution = response.choices[0].message.content
print(f"Proposed solution:\n{solution}")
# Out:
# Business area: Claims Processing Automation for Insurance
# Pain-point: Manual claims triage and document extraction from unstructured, inconsistent claim submissions, causing delays, errors, and high adjuster workload
# Proposed solution:
# ## Agentic AI Solution: Claims Triage & Document Extraction Copilot
#
# An **Agentic AI claims automation system** can act as a front-line “claims intake agent” that autonomously reads incoming claim submissions, extracts key details, classifies the claim, validates completeness, and routes it to the right workflow or adjuster with minimal human intervention.
#
# ---
#
# ### 1) Core Objective
# Reduce delays, errors, and adjuster workload by automating:
# - **Claims triage**
# - **Document classification**
# - **Data extraction from unstructured submissions**
# - **Missing-information detection**
# - **Priority and routing decisions**
#
# ---
#
# ### 2) How the Agentic AI Works
#
# #### A. Intake Agent
# The agent monitors incoming claims from:
# - Email attachments
# - Online claim portals
# - PDFs, scans, photos
# - Faxed documents
# - Agent/broker submissions
#
# It automatically:
# - Detects new claims
# - Groups related documents into one claim file
# - Identifies claim type, line of business, and likely severity
#
# ---
#
# #### B. Document Understanding Agent
# Using OCR + document AI + LLM reasoning, the agent:
# - Extracts structured fields from inconsistent documents
# - Handles handwritten notes, varying templates, and partial forms
# - Recognizes key artifacts such as:
#   - Claim forms
#   - Police reports
#   - Medical bills
#   - Repair estimates
#   - Photos
#   - Proof of loss
#   - Correspondence
#
# Example extracted fields:
# - Policy number
# - Claimant name
# - Date of loss
# - Loss type
# - Incident description
# - Injured parties
# - Estimated damage
# - Provider information
#
# ---
#
# #### C. Triage Agent
# This agent evaluates each claim and decides:
# - **Priority level**: urgent, standard, low risk
# - **Routing destination**: auto, property, liability, bodily injury, fraud review, etc.
# - **Straight-through processing eligibility**
# - **Need for human review**
#
# It uses rules + AI reasoning such as:
# - Missing key information
# - Low-complexity vs. complex claim
# - Potential fraud indicators
# - Severity signals
# - Coverage mismatch
# - Regulatory or SLA urgency
#
# ---
#
# #### D. Validation & Gap-Filling Agent
# The system checks whether the submission is complete and consistent:
# - Confirms required documents are present
# - Detects mismatches between documents
# - Flags ambiguous or contradictory information
# - Generates a request for missing info automatically
#
# It can even draft a message to the claimant:
# > “We received your claim, but we still need the repair estimate and incident date confirmation to continue processing.”
#
# ---
#
# #### E. Human-in-the-Loop Exception Agent
# For uncertain or high-risk cases, the AI escalates to a human adjuster:
# - Low confidence extraction
# - Suspected fraud
# - Severe claims
# - Legal complexity
# - Coverage disputes
#
# The adjuster receives:
# - Pre-populated claim summary
# - Extracted evidence
# - AI-generated rationale for triage
# - Confidence scores
# - Suggested next actions
#
# ---
#
# ### 3) Agentic Workflow Example
#
# 1. Claim arrives via email with photos and a scanned accident report
# 2. Intake agent creates a claim workspace
# 3. Extraction agent pulls key details from documents
# 4. Triage agent classifies it as “auto property damage, moderate severity”
# 5. Validation agent spots a missing policy number
# 6. System auto-generates a request for the missing policy information
# 7. Claim is routed to the correct adjuster queue with a summary
# 8. If severity exceeds threshold, the system escalates immediately
#
# ---
#
# ### 4) Key Capabilities
#
# #### Intelligent Document Processing
# - OCR for scanned and photographed documents
# - LLM-based extraction from messy, inconsistent formats
# - Entity normalization and deduplication
#
# #### Autonomous Decision Support
# - Claim prioritization
# - Routing
# - Confidence scoring
# - SLA-aware escalation
#
# #### Workflow Orchestration
# - Integrates with claims management systems
# - Creates tasks automatically
# - Sends notifications and follow-ups
# - Tracks status end-to-end
#
# #### Continuous Learning
# - Learns from adjuster corrections
# - Improves extraction and triage accuracy over time
# - Adapts to new document types and claim patterns
#
# ---
#
# ### 5) Business Impact
#
# #### Operational Benefits
# - Faster claim intake and first notice of loss processing
# - Reduced manual data entry
# - Lower adjuster backlog
# - Fewer errors and rework loops
# - Better compliance with SLA timelines
#
# #### Financial Benefits
# - Lower handling costs
# - Improved throughput
# - Better loss control through faster triage
# - Reduced leakage from missed or delayed information
#
# #### Customer Benefits
# - Faster acknowledgment and resolution
# - Fewer follow-up requests
# - Better claims experience and transparency
#
# ---
#
# ### 6) Recommended Architecture
#
# - **Ingestion layer**: email, portal, API, scanned docs
# - **Document AI/OCR layer**: text extraction from files and images
# - **LLM reasoning layer**: classify, summarize, infer, validate
# - **Rules engine**: policy rules, routing logic, compliance checks
# - **Workflow engine**: tasks, escalations, notifications
# - **Human review console**: approve, correct, override
# - **Analytics layer**: SLA tracking, triage accuracy, bottleneck analysis
#
# ---
#
# ### 7) Governance and Controls
# To ensure safe adoption:
# - Confidence thresholds for autonomous actions
# - Audit trail of every AI decision
# - Role-based access and PII protection
# - Explainability for triage decisions
# - Human approval for high-impact actions
# - Monitoring for drift, bias, and extraction errors
#
# ---
#
# ### 8) Example Outcome
# With this solution, insurers can:
# - Automate a large share of initial claim intake
# - Reduce adjuster time spent on manual document review
# - Accelerate routing and response times
# - Improve consistency across claims handling
#
# ---
#
# If you want, I can also provide this as:
# 1. a **one-slide executive summary**,
# 2. a **detailed architecture diagram**, or
# 3. a **step-by-step agent workflow with tools and prompts**.
